# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import re
driver = webdriver.Chrome(executable_path='./chromedriver.exe')
url = 'https://petitions.assembly.go.kr/'
driver.get(url)
time.sleep(3)
driver.find_element(By.XPATH,r'//*[@id="mainMenu_list"]/li[3]/div[1]/a').click()
time.sleep(3)
driver.find_element(By.XPATH,r'//*[@id="navsubbar"]/ul/li[2]/a').click()
time.sleep(3)
text = ''
for i in range(1,9):
    driver.find_element(By.XPATH,r'//*[@id="contentsbody"]/div/div/div[4]/div[2]/div[2]/ul/li['+str(i)+']/div/a/dl/dd').click()
    time.sleep(2)
    text += driver.find_element(By.XPATH,r'//*[@id="contentsbody"]/div/div/div[3]/div[2]/dl[3]/dd').text
    driver.back()
    
text_list = []

def word_list(list):
    words = []
    word_list = []
    for li in list:
        li = re.sub(r'\s+',' ',li)
        li = li.replace('\n','')
        li = li.replace('\r','')
        li = li.replace('\"','')
        li = li.replace('#','')
        li = li.replace('!','')
        li = li.replace(',','')
        li = li.replace('.','')
        li = li.replace('‘','')
        li = li.replace('’','')
        li = li.replace('“','')
        li = li.replace('”','')
        words = li.split(' ')
        word_list.append(words)
        
    flat_list = []
    for l in word_list:
        for item in l:
            flat_list.append(item)
            
    word_dict = {}
    for word in flat_list:
        if word not in word_dict:
            word_dict[word] = 1
        else:
            word_dict[word] += 1
    for key, values in word_dict.items():
        print(key,values)
        
word_list(text)
# Out:
# C:\Users\big303\AppData\Local\Temp\ipykernel_11500\404658572.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='./chromedriver.exe')
# 안 23
# 녕 1
# 하 119
# 십 9
# 니 116
# 까 10
#  4628
# 세 9
# 계 11
# 최 29
# 대 40
# 암 29
# 학 5
# 회 25
# 인 55
# A 4
# S 2
# C 2
# O 2
# ( 20
# 미 14
# 국 56
# 임 26
# 상 31
# 종 13
# 양 3
# ) 26
# 의 239
# 술 2
# 에 126
# 서 38
# 기 100
# 립 4
# 박 4
# 수 83
# 가 95
# 터 4
# 졌 2
# 지 91
# 만 23
# 내 23
# 유 35
# 방 17
# 환 24
# 자 51
# 는 133
# 한 97
# 숨 1
# 쉬 1
# 고 92
# 있 84
# 다 143
# 사 84
# 를 50
# 봤 1
# 습 45
# 엔 10
# 허 19
# 투 14
# 라 29
# 신 7
# 약 19
# 이 150
# 존 7
# 항 22
# 제 72
# 와 16
# 비 19
# 교 4
# 해 54
# 질 10
# 병 9
# 진 17
# 행 20
# 및 8
# 망 3
# 위 50
# 험 4
# 을 102
# 7 16
# 2 46
# % 3
# 낮 1
# 추 2
# 염 1
# 토 3
# 했 9
# 례 2
# 적 37
# 과 50
# 럽 3
# 많 2
# 은 64
# 들 30
# 통 6
# 삶 3
# 어 33
# 작 8
# 년 25
# 6 17
# 월 13
# 민 32
# 식 12
# 품 7
# 전 19
# 처 14
# 속 6
# 으 36
# 로 69
# 정 92
# 된 16
# 1 48
# 난 6
# 금 32
# ...
