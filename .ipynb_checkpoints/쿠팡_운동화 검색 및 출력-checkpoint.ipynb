# %%
# 쿠팡 -> 운동화 검색 -> 1~2페이지 -> 제목,가격

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import re
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome(executable_path='./chromedriver.exe')
driver.execute_cdp_cmd("Page.addScriptToEvaluateOnNewDocument", {"source": """ Object.defineProperty(navigator, 'webdriver', { get: () => undefined }) """})
url = 'https://www.coupang.com/'
driver.get(url)
time.sleep(3)

driver.find_element(By.XPATH,r'//*[@id="headerSearchKeyword"]').send_keys('운동화')
time.sleep(2)
driver.find_element(By.XPATH,r'//*[@id="headerSearchBtn"]').click()
time.sleep(2)

# BeautifulSoup
html = driver.page_source
bs = BeautifulSoup(html,'html.parser')

titles = bs.find_all('div',{'class':'name'});
costs = bs.find_all('strong',{'class':'price-value'});
for t,c in zip(titles,costs):
    print('상품 :',t.string.replace(' ','').replace('\n',''))
    print('가격 :',c.string)
    print()
# Out:
# C:\Users\big303\AppData\Local\Temp\ipykernel_9648\15956841.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='./chromedriver.exe')
# 상품 : 아식스젤컨텐드7MEN4E운동화1011B039-001
# 가격 : 50,110
#
# 상품 : 알타이카남성용등산운동작업트레킹화AT-01
# 가격 : 39,500
#
# 상품 : 밸롭티바트니트런닝화BS02010001
# 가격 : 57,520
#
# 상품 : VENTURA운동화처럼예쁘고편한작업화A-20
# 가격 : 36,100
#
# 상품 : 밸롭봄버에어초경량어글리슈즈BA07010027
# 가격 : 52,250
#
# 상품 : 레이시스남성여성다이얼운동화에어런닝화워킹화트레킹화신발RXT77711002X
# 가격 : 29,800
#
# 상품 : 휠라레인저운동화1RM01141E
# 가격 : 36,490
#
# 상품 : 휠라레이트레이서운동화1RM01153_926
# 가격 : 44,900
#
# 상품 : 휠라아동용레이KD운동화3RM01150D
# 가격 : 40,180
#
# 상품 : 유세븐생활방수운동화DM프루프
# 가격 : 25,900
#
# 상품 : 휠라펑키테니스19981TM00622E
# 가격 : 30,890
#
# 상품 : 휠라디사이퍼운동화1GM00828E
# 가격 : 35,300
#
# 상품 : 밸롭봄버에어초경량어글리슈즈BA07010027
# 가격 : 52,250
#
# 상품 : 페이퍼플레인울트라메시운동화PP1447
# 가격 : 31,280
#
# 상품 : 휠라디사이퍼운동화1GM00828D
# 가격 : 35,300
#
# 상품 : 유세븐생활방수운동화DM프루프
# 가격 : 25,900
#
# 상품 : 휠라아동용레이KD운동화3RM01150D
# 가격 : 40,180
# ...
